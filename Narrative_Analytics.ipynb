# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

artists = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/artist_data.csv')
works = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/artwork_data.csv')
# Out:
# /Users/atpathak/opt/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
artists
# Out:
#          id                    name  gender      dates  yearOfBirth  \
# 0     10093  Abakanowicz, Magdalena  Female  born 1930       1930.0
# 1         0     Abbey, Edwin Austin    Male  1852–1911       1852.0
# 2      2756        Abbott, Berenice  Female  1898–1991       1898.0
# 3         1  Abbott, Lemuel Francis    Male  1760–1803       1760.0
# 4       622          Abrahams, Ivor    Male  born 1935       1935.0
# ...     ...                     ...     ...        ...          ...
# 3527  12542         Zorio, Gilberto    Male  born 1944       1944.0
# 3528   2186              Zox, Larry    Male  born 1936       1936.0
# 3529    621   Zuccarelli, Francesco    Male  1702–1788       1702.0
# 3530   2187        Zuloaga, Ignacio    Male  1870–1945       1870.0
# 3531   2188         Zyw, Aleksander    Male  1905–1995       1905.0
#
#       yearOfDeath                    placeOfBirth            placeOfDeath  \
# 0             NaN                          Polska                     NaN
# 1          1911.0     Philadelphia, United States  London, United Kingdom
# 2          1991.0      Springfield, United States   Monson, United States
# 3          1803.0  Leicestershire, United Kingdom  London, United Kingdom
# 4             NaN           Wigan, United Kingdom                     NaN
# ...           ...                             ...                     ...
# 3527          NaN           Andorno Micca, Italia                     NaN
# 3528          NaN       Des Moines, United States                     NaN
# 3529       1788.0                          Italia                 Firenze
# 3530       1945.0                          España                  España
# 3531       1995.0                          Polska                     NaN
#
#                                                     url
# 0     http://www.tate.org.uk/art/artists/magdalena-a...
# 1     http://www.tate.org.uk/art/artists/edwin-austi...
# 2     http://www.tate.org.uk/art/artists/berenice-ab...
# 3     http://www.tate.org.uk/art/artists/lemuel-fran...
# 4     http://www.tate.org.uk/art/artists/ivor-abraha...
# ...                                                 ...
# 3527  http://www.tate.org.uk/art/artists/gilberto-zo...
# 3528  http://www.tate.org.uk/art/artists/larry-zox-2186
# 3529  http://www.tate.org.uk/art/artists/francesco-z...
# 3530  http://www.tate.org.uk/art/artists/ignacio-zul...
# 3531  http://www.tate.org.uk/art/artists/aleksander-...
#
# [3532 rows x 9 columns]

# %%
works
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# 0      A Figure Bowing before a Seated Old Man with h...
# 1      Two Drawings of Frightened Figures, Probably f...
# 2      The Preaching of Warning. Verso: An Old Man En...
# 3         Six Drawings of Figures with Outstretched Arms
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...                                                  ...
# 69196                        Larvae (from Tampax Romana)
# 69197                   Living Womb (from Tampax Romana)
# 69198                                      Present Tense
# 69199          Work No. 227: The lights going on and off
# 69200                   Dancing Scene in the West Indies
#
#                      dateText  \
# 0              date not known
# 1              date not known
# 2                     ?c.1785
# 3              date not known
# 4      1826–7, reprinted 1892
# ...                       ...
# 69196                    1975
# 69197                    1976
# 69198                    1996
# 69199                    2000
# 69200                 1764–96
#
#                                                   medium  \
# 0      Watercolour, ink, chalk and graphite on paper....
# 1                                      Graphite on paper
# 2            Graphite on paper. Verso: graphite on paper
# 3                                      Graphite on paper
# 4                                Line engraving on paper
# ...                                                  ...
# 69196   Perspex, Wood, hairpiece, tampon and human blood
# 69197  Wood, Perspex, plastic, photograph on paper, t...
# 69198                               Soap and glass beads
# 69199                                   Gallery lighting
# 69200                                Oil paint on canvas
#
#                                               creditLine  year  \
# 0                    Presented by Mrs John Richmond 1922   NaN
# 1                    Presented by Mrs John Richmond 1922   NaN
# 2                    Presented by Mrs John Richmond 1922  1785
# 3                    Presented by Mrs John Richmond 1922   NaN
# 4      Purchased with the assistance of a special gra...  1826
# ...                                                  ...   ...
# 69196                 Transferred from Tate Archive 2012  1975
# 69197                 Transferred from Tate Archive 2012  1976
# 69198                     Presented by Tate Members 2013  1996
# 69199  Purchased with funds provided by Tate Members,...  2000
# 69200  Purchased with assistance from Tate Patrons an...  1764
#
#        acquisitionYear                           dimensions width height  \
# 0               1922.0                support: 394 x 419 mm   394    419
# 1               1922.0                support: 311 x 213 mm   311    213
# 2               1922.0                support: 343 x 467 mm   343    467
# 3               1922.0                support: 318 x 394 mm   318    394
# 4               1919.0                  image: 243 x 335 mm   243    335
# ...                ...                                  ...   ...    ...
# 69196           2013.0           object: 305 x 305 x 135 mm   305    305
# 69197           2013.0           object: 305 x 305 x 135 mm   305    305
# 69198           2013.0       displayed: 45 x 2410 x 2990 mm    45   2410
# 69199           2013.0  Overall display dimensions variable   NaN    NaN
# 69200           2013.0            unconfirmed: 508 x 660 mm   508    660
#
#         depth units inscription thumbnailCopyright  \
# 0         NaN    mm         NaN                NaN
# 1         NaN    mm         NaN                NaN
# 2         NaN    mm         NaN                NaN
# 3         NaN    mm         NaN                NaN
# 4         NaN    mm         NaN                NaN
# ...       ...   ...         ...                ...
# 69196   135.0    mm         NaN                NaN
# 69197   135.0    mm         NaN                NaN
# 69198  2990.0    mm         NaN                NaN
# 69199     NaN   NaN         NaN                NaN
# 69200     NaN    mm         NaN                NaN
#
#                                             thumbnailUrl  \
# 0      http://www.tate.org.uk/art/images/work/A/A00/A...
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69196                                                NaN
# 69197                                                NaN
# 69198                                                NaN
# 69199                                                NaN
# 69200  http://www.tate.org.uk/art/images/work/T/T13/T...
#
#                                                      url
# 0      http://www.tate.org.uk/art/artworks/blake-a-fi...
# 1      http://www.tate.org.uk/art/artworks/blake-two-...
# 2      http://www.tate.org.uk/art/artworks/blake-the-...
# 3      http://www.tate.org.uk/art/artworks/blake-six-...
# 4      http://www.tate.org.uk/art/artworks/blake-the-...
# ...                                                  ...
# 69196  http://www.tate.org.uk/art/artworks/p-orridge-...
# 69197  http://www.tate.org.uk/art/artworks/p-orridge-...
# 69198  http://www.tate.org.uk/art/artworks/hatoum-pre...
# 69199  http://www.tate.org.uk/art/artworks/creed-work...
# 69200  http://www.tate.org.uk/art/artworks/brunias-da...
#
# [69201 rows x 20 columns]

# %%
works.artist.value_counts().head(20).plot(kind='bar')
plt.ylabel('Artworks Count')
# Out:
# Text(0, 0.5, 'Artworks Count')

# %%
works.artist.value_counts().head(50)[1:51].plot(kind='bar', figsize=(10,5))
plt.ylabel('Artworks Count')
# Out:
# Text(0, 0.5, 'Artworks Count')

# %%
len(artists)
# Out:
# 3532

# %%
locations = artists.placeOfBirth.str.split(',', 1).tolist()
locations = [x for x in locations if str(x) != 'nan']
#print(locations)
countries = []

for entry in locations:
    c = entry[-1]
    c = c.strip()
    countries.append(c)

#print(countries)

countries = pd.DataFrame(countries, columns=['country'])
#countries
cntry_counts = pd.DataFrame(countries.country.value_counts())
other = int(cntry_counts[10:].sum())
cntry_counts = cntry_counts[:10]
cntry_counts.loc[11] = other
cntry_counts = cntry_counts.rename(index={11: 'Other'})
#cntry_counts
# Generate Pie Chart
plt.figure(figsize=(10, 5))
plt.pie(cntry_counts.country)
plt.axis('equal')
plt.title('Artists Country of Birth')
plt.legend(cntry_counts.index)

# %%
plt.plot(artists.yearOfBirth.value_counts().sort_index())
plt.title('Artists Born by Year')
# Out:
# Text(0.5, 1.0, 'Artists Born by Year')

# %%
acquisition_df = pd.DataFrame(works.acquisitionYear.value_counts())
acquisition_df = acquisition_df.sort_index()
plt.plot(acquisition_df)
plt.ylabel('Works Acquired')
# Out:
# Text(0, 0.5, 'Works Acquired')

# %%
acquisition_df = pd.DataFrame(works[works.artist != 'Turner, Joseph Mallord William'].acquisitionYear.value_counts())
acquisition_df = acquisition_df.sort_index()
plt.plot(acquisition_df)
plt.ylabel('Works Acquired')
# Out:
# Text(0, 0.5, 'Works Acquired')

# %%
living = pd.DataFrame(artists.yearOfDeath.isnull())
living = pd.DataFrame(living.yearOfDeath.value_counts())
living.plot(kind='bar', legend=False)
plt.title('Artists Who are No Longer Living')
# Out:
# Text(0.5, 1.0, 'Artists Who are No Longer Living')

# %%
works.medium.value_counts().head(10)
# Out:
# Graphite on paper                            26167
# Oil paint on canvas                           3383
# Screenprint on paper                          2984
# Lithograph on paper                           2721
# Watercolour on paper                          1890
# Etching on paper                              1793
# Graphite and watercolour on paper             1680
# Ink on paper                                   880
# Intaglio print on paper                        820
# Photograph, gelatin silver print on paper      750
# Name: medium, dtype: int64

# %%
# Remove Turner
turnerless_artworks = works[works['artist'] != 'Turner, Joseph Mallord William']
# Coerce to Numeric
turnerless_artworks.height = pd.to_numeric(turnerless_artworks.height, errors = 'coerce')
turnerless_artworks.width = pd.to_numeric(turnerless_artworks.width, errors = 'coerce')
turnerless_artworks.depth = pd.to_numeric(turnerless_artworks.depth, errors = 'coerce')
turnerless_artworks = turnerless_artworks[turnerless_artworks['units']=='mm']
turnerless_artworks = turnerless_artworks[turnerless_artworks.height.notnull()]

## The error is just because of how we did the conditional select and we don't need to be worried about it...
# Out:
# /Users/atpathak/opt/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Aggregate to new medium_agg column
turnerless_artworks['medium_agg'] = 'other'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("paper", na=False),'medium_agg'] = 'paper'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("canvas", na=False),'medium_agg'] = 'canvas'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("wood", na=False),'medium_agg'] = 'wood'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("paint on", na=False),'medium_agg'] = 'other painted panel'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("Bronze", na=False),'medium_agg'] = 'sculpture'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("Plaster", na=False),'medium_agg'] = 'sculpture'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("Marble", na=False),'medium_agg'] = 'sculpture'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("Stone", na=False),'medium_agg'] = 'sculpture'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("plate", na=False),'medium_agg'] = 'plate'
turnerless_artworks.loc[turnerless_artworks['medium'].str.contains("photograph", na=False),'medium_agg'] = 'photo'

turnerless_artworks['surface'] = turnerless_artworks.height * turnerless_artworks.width
turnerless_artworks
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69195  122959           T13864  P-Orridge, Genesis     artist     16646
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# 0      A Figure Bowing before a Seated Old Man with h...
# 1      Two Drawings of Frightened Figures, Probably f...
# 2      The Preaching of Warning. Verso: An Old Man En...
# 3         Six Drawings of Figures with Outstretched Arms
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...                                                  ...
# 69195   It’s That Time Of The Month (from Tampax Romana)
# 69196                        Larvae (from Tampax Romana)
# 69197                   Living Womb (from Tampax Romana)
# 69198                                      Present Tense
# 69200                   Dancing Scene in the West Indies
#
#                      dateText  \
# 0              date not known
# 1              date not known
# 2                     ?c.1785
# 3              date not known
# 4      1826–7, reprinted 1892
# ...                       ...
# 69195                    1975
# 69196                    1975
# 69197                    1976
# 69198                    1996
# 69200                 1764–96
#
#                                                   medium  \
# 0      Watercolour, ink, chalk and graphite on paper....
# 1                                      Graphite on paper
# 2            Graphite on paper. Verso: graphite on paper
# 3                                      Graphite on paper
# 4                                Line engraving on paper
# ...                                                  ...
# 69195  Wood, Perspex, clock case, tampons and human b...
# 69196   Perspex, Wood, hairpiece, tampon and human blood
# 69197  Wood, Perspex, plastic, photograph on paper, t...
# 69198                               Soap and glass beads
# 69200                                Oil paint on canvas
#
#                                               creditLine  year  ...  width  \
# 0                    Presented by Mrs John Richmond 1922   NaN  ...  394.0
# 1                    Presented by Mrs John Richmond 1922   NaN  ...  311.0
# 2                    Presented by Mrs John Richmond 1922  1785  ...  343.0
# 3                    Presented by Mrs John Richmond 1922   NaN  ...  318.0
# 4      Purchased with the assistance of a special gra...  1826  ...  243.0
# ...                                                  ...   ...  ...    ...
# 69195                 Transferred from Tate Archive 2012  1975  ...  305.0
# 69196                 Transferred from Tate Archive 2012  1975  ...  305.0
# 69197                 Transferred from Tate Archive 2012  1976  ...  305.0
# 69198                     Presented by Tate Members 2013  1996  ...   45.0
# 69200  Purchased with assistance from Tate Patrons an...  1764  ...  508.0
#
#        height   depth  units  inscription   thumbnailCopyright  \
# 0       419.0     NaN     mm          NaN                  NaN
# 1       213.0     NaN     mm          NaN                  NaN
# 2       467.0     NaN     mm          NaN                  NaN
# 3       394.0     NaN     mm          NaN                  NaN
# 4       335.0     NaN     mm          NaN                  NaN
# ...       ...     ...    ...          ...                  ...
# 69195   305.0   135.0     mm          NaN  © Genesis P-Orridge
# 69196   305.0   135.0     mm          NaN                  NaN
# 69197   305.0   135.0     mm          NaN                  NaN
# 69198  2410.0  2990.0     mm          NaN                  NaN
# 69200   660.0     NaN     mm          NaN                  NaN
#
#                                             thumbnailUrl  \
# 0      http://www.tate.org.uk/art/images/work/A/A00/A...
# 1      http://www.tate.org.uk/art/images/work/A/A00/A...
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 3      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69195  http://www.tate.org.uk/art/images/work/T/T13/T...
# 69196                                                NaN
# 69197                                                NaN
# 69198                                                NaN
# 69200  http://www.tate.org.uk/art/images/work/T/T13/T...
#
#                                                      url           medium_agg  \
# 0      http://www.tate.org.uk/art/artworks/blake-a-fi...                paper
# 1      http://www.tate.org.uk/art/artworks/blake-two-...                paper
# 2      http://www.tate.org.uk/art/artworks/blake-the-...                paper
# 3      http://www.tate.org.uk/art/artworks/blake-six-...                paper
# 4      http://www.tate.org.uk/art/artworks/blake-the-...                paper
# ...                                                  ...                  ...
# 69195  http://www.tate.org.uk/art/artworks/p-orridge-...                other
# 69196  http://www.tate.org.uk/art/artworks/p-orridge-...                other
# 69197  http://www.tate.org.uk/art/artworks/p-orridge-...                photo
# 69198  http://www.tate.org.uk/art/artworks/hatoum-pre...                other
# 69200  http://www.tate.org.uk/art/artworks/brunias-da...  other painted panel
#
#         surface
# 0      165086.0
# 1       66243.0
# 2      160181.0
# 3      125292.0
# 4       81405.0
# ...         ...
# 69195   93025.0
# 69196   93025.0
# 69197   93025.0
# 69198  108450.0
# 69200  335280.0
#
# [27293 rows x 22 columns]

# %%
turnerless_artworks[['medium_agg','height','width','depth','surface']].groupby('medium_agg').describe()
# Out:
#                       height                                                   \
#                        count         mean          std    min     25%     50%
# medium_agg
# canvas                 260.0  1776.396154  1543.269130  105.0  729.25  1512.5
# other                 1301.0  1189.179554  1866.683697    6.0  273.00   620.0
# other painted panel   4408.0  1032.772913   820.503273   45.0  514.00   787.0
# paper                19800.0   417.212288   379.088368   15.0  200.00   320.0
# photo                  192.0  1286.786458  2106.887208   90.0  303.50   690.0
# plate                  344.0   347.148256   478.247577   76.0  305.00   305.0
# sculpture              639.0   619.608764   791.822922   18.0  222.00   406.0
# wood                   349.0  1067.189112  1597.806055   30.0  340.00   611.0
#
#                                          width               ...    depth  \
#                          75%      max    count         mean  ...      75%
# medium_agg                                                   ...
# canvas               2290.75  16000.0    259.0  1495.119691  ...    53.00
# other                1460.00  37500.0   1298.0   960.942604  ...   750.00
# other painted panel  1270.00  11900.0   4408.0   960.962568  ...    55.00
# paper                 559.00  10619.0  19780.0   407.575925  ...   184.00
# photo                1395.25  19890.0    190.0   973.368421  ...   146.50
# plate                 305.00   8850.0    344.0   264.523256  ...  1107.75
# sculpture             714.50  11250.0    639.0   765.388106  ...   445.00
# wood                 1073.00  14850.0    349.0  1065.908309  ...   510.00
#
#                               surface                                       \
#                          max    count          mean           std      min
# medium_agg
# canvas                2185.0    259.0  3.424765e+06  3.831638e+06  12600.0
# other                18290.0   1298.0  1.880836e+06  4.996881e+06   1681.0
# other painted panel   5486.0   4408.0  1.392090e+06  2.247036e+06   3306.0
# paper                 5000.0  19780.0  2.608455e+05  7.540381e+05    237.0
# photo                 2015.0    190.0  2.408794e+06  6.188098e+06  13320.0
# plate                12360.0    344.0  1.258063e+05  4.437804e+05   7752.0
# sculpture             5800.0    639.0  6.975306e+05  1.405889e+06   1296.0
# wood                  6300.0    349.0  2.160677e+06  8.422669e+06   6300.0
#
#
#                           25%        50%        75%          max
# medium_agg
# canvas               551863.5  2283380.0  4707935.5   21731950.0
# other                 87543.5   395599.5  1597850.0   91253940.0
# other painted panel  291732.5   624755.0  1558060.5   36233100.0
# paper                 39042.0   102994.0   315810.0   32376000.0
# photo                 98967.5   388417.5  1696120.0   54315000.0
# plate                 69845.0    69845.0    69845.0    6549000.0
# sculpture             77770.5   203200.0   662296.5   17964018.0
# wood                 141600.0   496600.0  1247400.0  132462000.0
#
# [8 rows x 32 columns]

# %%
turnerless_artworks[['medium_agg', 'height']].boxplot(by='medium_agg', figsize=(10,20))
